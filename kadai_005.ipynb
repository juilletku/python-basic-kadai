# %% [markdown]
# <a href="https://colab.research.google.com/github/juilletku/python-basic-kadai/blob/main/kadai_005.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
top_base = 10 #cm
bottom_base = 20 #cm
height = 5 #cm

#台形の面積 =（上辺＋下辺）× 高さ ÷ 2
print((top_base + bottom_base) * height / 2)
# Out:
# 75.0
