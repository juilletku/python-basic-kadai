# %%
arrays = ["水","金","地","火","木","土","天","海","冥"]
target ="冥"
for array in arrays:
  print(array)
  if (array == target):
    continue
for array in arrays:
  print(array)
  if (array == target):
    break
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
